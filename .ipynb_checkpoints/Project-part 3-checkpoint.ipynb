# %%
import pandas as pd


spd_data = pd.read_csv("SPD(League only).csv")

amount = spd_data.groupby(by=['State'])['Amount'].sum()
amount = amount.sort_values(ascending = False)

state = list(amount.index)
state = [i.strip()for i in state]
data = [list(z) for z in zip(state, list(amount))]
max_amount = max(amount)
# Out:
#   File "<ipython-input-5-1fc5c8519df0>", line 2
#     pip install pyecharts
#         ^
# SyntaxError: invalid syntax

# %%
number = spd_data.groupby(by=['State'])['Amount'].count()
number = number.sort_values(ascending = False)

state_donate_number = list(number.index)
state_donate_number = [i.strip()for i in state_donate_number]
number_data = [list(z) for z in zip(state_donate_number, list(number))]
max_number = max(number)
print(number_data)
print(max_number)
# Out:
# [['California', 468], ['Illinois', 423], ['Florida', 414], ['Ohio', 255], ['Washington', 179], ['Pennsylvania', 161], ['Arizona', 156], ['Indiana', 142], ['Minnesota', 125], ['New York', 125], ['North Carolina', 119], ['Oregon', 108], ['New Jersey', 98], ['Texas', 81], ['Wisconsin', 63], ['Massachusetts', 57], ['D.C.', 54], ['Georgia', 44], ['Missouri', 34], ['Maryland', 28], ['Colorado', 27], ['Georgia', 22], ['Neveda', 21], ['Michigan', 21], ['Utah', 21], ['Tennessee', 15], ['Oklahoma', 14], ['Nevada', 3], ['Louisiana', 2]]
# 468

# %%
from pyecharts import options as opts
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-9e9da777dcc2> in <module>
# ----> 1 from pyecharts import options as opts
#
# ModuleNotFoundError: No module named 'pyecharts'

# %%
from pyecharts.charts import Pie

pie = Pie().add("Donation Amount",
                data,
                radius = ["20%", "80%"],
                center = ["60%", "60%"],
                rosetype = "radius")

pie.set_global_opts(title_opts = opts.TitleOpts(title="Political Donation Amount by State",
                                                pos_right = '60%'),
                    legend_opts = opts.LegendOpts(
                                                orient='vertical',
                                                pos_right="75.7%",
                                                pos_top="20%"))
pie.set_series_opts(label_opts = opts.LabelOpts(formatter="{b} : {d}%"))    
pie.render_notebook()

# %%
pie = Pie().add("# of Sport Owners donated",
                number_data,
                radius = ["20%", "80%"],
                center = ["60%", "60%"],
                rosetype = "radius")

pie.set_global_opts(title_opts = opts.TitleOpts(title="# of Sport Owners donated in each State",
                                                pos_right = '60%'),
                    legend_opts = opts.LegendOpts(
                                                orient='vertical',
                                                pos_right="77%",
                                                pos_top="20%"))
pie.set_series_opts(label_opts = opts.LabelOpts(formatter="{b} : {d}%"))    
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1befeba5e7c140578fc9e193153c4889" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1befeba5e7c140578fc9e193153c4889 = echarts.init(
#                     document.getElementById('1befeba5e7c140578fc9e193153c4889'), 'white', {renderer: 'canvas'});
#                 var option_1befeba5e7c140578fc9e193153c4889 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "# of Sport Owners donated",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "California",
#                     "value": 468
#                 },
#                 {
#                     "name": "Illinois",
#                     "value": 423
#                 },
#                 {
#                     "name": "Florida",
#                     "value": 414
#                 },
#                 {
#                     "name": "Ohio",
#                     "value": 255
#                 },
#                 {
#                     "name": "Washington",
#                     "value": 179
#                 },
#                 {
#                     "name": "Pennsylvania",
#                     "value": 161
#                 },
#                 {
#                     "name": "Arizona",
#                     "value": 156
#                 },
#                 {
#                     "name": "Indiana",
#                     "value": 142
#                 },
#                 {
#                     "name": "Minnesota",
#                     "value": 125
#                 },
#                 {
#                     "name": "New York",
#                     "value": 125
#                 },
#                 {
#                     "name": "North Carolina",
#                     "value": 119
#                 },
#                 {
#                     "name": "Oregon",
#                     "value": 108
#                 },
#                 {
#                     "name": "New Jersey",
#                     "value": 98
#                 },
#                 {
#                     "name": "Texas",
#                     "value": 81
#                 },
#                 {
#                     "name": "Wisconsin",
#                     "value": 63
#                 },
#                 {
#                     "name": "Massachusetts",
#                     "value": 57
#                 },
#                 {
#                     "name": "D.C.",
#                     "value": 54
#                 },
#                 {
#                     "name": "Georgia",
#                     "value": 44
#                 },
#                 {
#                     "name": "Missouri",
#                     "value": 34
#                 },
#                 {
#                     "name": "Maryland",
#                     "value": 28
#                 },
#                 {
#                     "name": "Colorado",
#                     "value": 27
#                 },
#                 {
#                     "name": "Georgia",
#                     "value": 22
#                 },
#                 {
#                     "name": "Neveda",
#                     "value": 21
#                 },
#                 {
#                     "name": "Michigan",
#                     "value": 21
#                 },
#                 {
#                     "name": "Utah",
#                     "value": 21
#                 },
#                 {
#                     "name": "Tennessee",
#                     "value": 15
#                 },
#                 {
#                     "name": "Oklahoma",
#                     "value": 14
#                 },
#                 {
#                     "name": "Nevada",
#                     "value": 3
#                 },
#                 {
#                     "name": "Louisiana",
#                     "value": 2
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "80%"
#             ],
#             "center": [
#                 "60%",
#                 "60%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b} : {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "California",
#                 "Illinois",
#                 "Florida",
#                 "Ohio",
#                 "Washington",
#                 "Pennsylvania",
#                 "Arizona",
#                 "Indiana",
#                 "Minnesota",
#                 "New York",
#                 "North Carolina",
#                 "Oregon",
#                 "New Jersey",
#                 "Texas",
#                 "Wisconsin",
#                 "Massachusetts",
#                 "D.C.",
#                 "Georgia",
#                 "Missouri",
#                 "Maryland",
#                 "Colorado",
#                 "Neveda",
#                 "Michigan",
#                 "Utah",
#                 "Tennessee",
#                 "Oklahoma",
#                 "Nevada",
#                 "Louisiana"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "77%",
#             "top": "20%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "# of Sport Owners donated in each State",
#             "right": "60%",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1befeba5e7c140578fc9e193153c4889.setOption(option_1befeba5e7c140578fc9e193153c4889);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

bar=(
    Bar()
        .add_xaxis(state)
        .add_yaxis("Donation Amount",list(amount))
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right"))
        .set_global_opts(title_opts=opts.TitleOpts(title="Political Donation Amount by State"))
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d4567418899346f497dcb174c49e7c9d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d4567418899346f497dcb174c49e7c9d = echarts.init(
#                     document.getElementById('d4567418899346f497dcb174c49e7c9d'), 'white', {renderer: 'canvas'});
#                 var option_d4567418899346f497dcb174c49e7c9d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Donation Amount",
#             "legendHoverLink": true,
#             "data": [
#                 15074549,
#                 6402863,
#                 4841282,
#                 4542741,
#                 3967479,
#                 2376951,
#                 2228972,
#                 2044070,
#                 1848500,
#                 1588995,
#                 1115500,
#                 1044021,
#                 922350,
#                 862170,
#                 712850,
#                 684260,
#                 556320,
#                 508039,
#                 428050,
#                 419800,
#                 372190,
#                 193100,
#                 189100,
#                 153750,
#                 92900,
#                 75916,
#                 50100,
#                 15000,
#                 5400
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Donation Amount"
#             ],
#             "selected": {
#                 "Donation Amount": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "California",
#                 "Illinois",
#                 "Ohio",
#                 "Florida",
#                 "New York",
#                 "Texas",
#                 "Maryland",
#                 "Pennsylvania",
#                 "Arizona",
#                 "North Carolina",
#                 "Indiana",
#                 "Neveda",
#                 "Georgia",
#                 "Washington",
#                 "Wisconsin",
#                 "Minnesota",
#                 "New Jersey",
#                 "D.C.",
#                 "Massachusetts",
#                 "Oregon",
#                 "Colorado",
#                 "Michigan",
#                 "Georgia",
#                 "Missouri",
#                 "Utah",
#                 "Tennessee",
#                 "Oklahoma",
#                 "Nevada",
#                 "Louisiana"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Political Donation Amount by State",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d4567418899346f497dcb174c49e7c9d.setOption(option_d4567418899346f497dcb174c49e7c9d);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

bar=(
    Bar()
        .add_xaxis(state_donate_number)
        .add_yaxis("# of Sport Owners donated",list(number))
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right"))
        .set_global_opts(title_opts=opts.TitleOpts(title="# of Sport Owners donated in each State"))
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cb1373294d52447798f8d8c885e4c7e8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cb1373294d52447798f8d8c885e4c7e8 = echarts.init(
#                     document.getElementById('cb1373294d52447798f8d8c885e4c7e8'), 'white', {renderer: 'canvas'});
#                 var option_cb1373294d52447798f8d8c885e4c7e8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "# of Sport Owners donated",
#             "legendHoverLink": true,
#             "data": [
#                 468,
#                 423,
#                 414,
#                 255,
#                 179,
#                 161,
#                 156,
#                 142,
#                 125,
#                 125,
#                 119,
#                 108,
#                 98,
#                 81,
#                 63,
#                 57,
#                 54,
#                 44,
#                 34,
#                 28,
#                 27,
#                 22,
#                 21,
#                 21,
#                 21,
#                 15,
#                 14,
#                 3,
#                 2
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "# of Sport Owners donated"
#             ],
#             "selected": {
#                 "# of Sport Owners donated": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "California",
#                 "Illinois",
#                 "Florida",
#                 "Ohio",
#                 "Washington",
#                 "Pennsylvania",
#                 "Arizona",
#                 "Indiana",
#                 "Minnesota",
#                 "New York",
#                 "North Carolina",
#                 "Oregon",
#                 "New Jersey",
#                 "Texas",
#                 "Wisconsin",
#                 "Massachusetts",
#                 "D.C.",
#                 "Georgia",
#                 "Missouri",
#                 "Maryland",
#                 "Colorado",
#                 "Georgia",
#                 "Neveda",
#                 "Michigan",
#                 "Utah",
#                 "Tennessee",
#                 "Oklahoma",
#                 "Nevada",
#                 "Louisiana"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "# of Sport Owners donated in each State",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_cb1373294d52447798f8d8c885e4c7e8.setOption(option_cb1373294d52447798f8d8c885e4c7e8);
#         });
#     </script>
