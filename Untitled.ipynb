# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("sports-political-donations.csv")

df
# Out:
#             Owner               Team League                     Recipient  \
# 0     Adam Silver       Commissioner    NBA                   WRIGHT 2016
# 1     Adam Silver       Commissioner    NBA           BIDEN FOR PRESIDENT
# 2     Adam Silver       Commissioner    NBA                     CORY 2020
# 3     Adam Silver       Commissioner    NBA  Kamala Harris for the People
# 4     Adam Silver       Commissioner    NBA               Win The Era PAC
# ...           ...                ...    ...                           ...
# 2793    Zygi Wilf  Minnesota Vikings    NFL      ANGIE CRAIG FOR CONGRESS
# 2794    Zygi Wilf  Minnesota Vikings    NFL    DEAN PHILLIPS FOR CONGRESS
# 2795    Zygi Wilf  Minnesota Vikings    NFL           MENENDEZ FOR SENATE
# 2796    Zygi Wilf  Minnesota Vikings    NFL      TINA SMITH FOR MINNESOTA
# 2797    Zygi Wilf  Minnesota Vikings    NFL   TOM MALINOWSKI FOR CONGRESS
#
#       Amount  Election Year     Party
# 0     4000.0           2016  Democrat
# 1     2800.0           2020  Democrat
# 2     2700.0           2020  Democrat
# 3     2700.0           2020  Democrat
# 4     2700.0           2020  Democrat
# ...      ...            ...       ...
# 2793  2700.0           2018  Democrat
# 2794  2700.0           2018  Democrat
# 2795  2700.0           2018  Democrat
# 2796  2700.0           2018  Democrat
# 2797  2700.0           2018  Democrat
#
# [2798 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2798 entries, 0 to 2797
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Owner          2798 non-null   object
#  1   Team           2798 non-null   object
#  2   League         2798 non-null   object
#  3   Recipient      2798 non-null   object
#  4   Amount         2798 non-null   float64
#  5   Election Year  2798 non-null   int64
#  6   Party          2789 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 153.1+ KB

# %%
df_filt = df.loc[df["Party"]== "Republican"]
df_filt
# Out:
#                        Owner                           Team  League  \
# 20          Amy Adams Strunk               Tennessee Titans     NFL
# 21          Amy Adams Strunk               Tennessee Titans     NFL
# 22           Andrew Murstein      Richard Petty Motorsports  NASCAR
# 24               Arte Moreno  Los Angeles Angels of Anaheim     MLB
# 27               Arte Moreno  Los Angeles Angels of Anaheim     MLB
# ...                      ...                            ...     ...
# 2770  W. Joseph Williams Jr.                Cincinnati Reds     MLB
# 2771  W. Joseph Williams Jr.                Cincinnati Reds     MLB
# 2772  W. Joseph Williams Jr.                Cincinnati Reds     MLB
# 2774  W. Joseph Williams Jr.                Cincinnati Reds     MLB
# 2776  W. Joseph Williams Jr.                Cincinnati Reds     MLB
#
#                                     Recipient   Amount  Election Year  \
# 20               Portman for Senate Committee   2700.0           2016
# 21              Republican National Committee    400.0           2016
# 22                          Right to Rise USA   1000.0           2016
# 24    MCCONNELL FOR MAJORITY LEADER COMMITTEE  10600.0           2020
# 27                        COLLINS FOR SENATOR   5600.0           2020
# ...                                       ...      ...            ...
# 2770                                TEAM RYAN   2500.0           2016
# 2771                    WENSTRUP FOR CONGRESS   2000.0           2016
# 2772               BRAD WENSTRUP VICTORY FUND   1500.0           2018
# 2774           PORTMAN-OHIO VICTORY COMMITTEE   1000.0           2016
# 2776                                TEAM JOSH    400.0           2018
#
#            Party
# 20    Republican
# 21    Republican
# 22    Republican
# 24    Republican
# 27    Republican
# ...          ...
# 2770  Republican
# 2771  Republican
# 2772  Republican
# 2774  Republican
# 2776  Republican
#
# [1625 rows x 7 columns]

# %%
df_grp = df.groupby(["League"], as_index=False)['Amount'].count().sort_values(['Amount'],ascending=False)
df_grp.set_index('League')
df_grp
# Out:
#             League  Amount
# 0              MLB     746
# 5              NBA     462
# 12             NFL     444
# 13             NHL     329
# 15            WNBA     274
# 11       NBA, WNBA     118
# 7         NBA, NFL     109
# 9         NBA, NHL     109
# 6         NBA, MLB      84
# 4           NASCAR      79
# 10  NBA, NHL, WNBA      15
# 14        NHL, NFL      12
# 2         MLB, NHL       7
# 3        MLB, WNBA       6
# 8    NBA, NFL, NHL       3
# 1      MLB, NASCAR       1

# %%
dfgr = df.groupby(['Party'],as_index=False)['Amount'].sum().sort_values(['Amount'],ascending=False)
dfgr.drop(dfgr.index[dfgr['Party'] == 'Independent'], inplace=True)
dfgr.drop(dfgr.index[dfgr['Party'] == 'Bipartisan, but mostly Republican'], inplace=True)
dfgr.drop(dfgr.index[dfgr['Party'] == 'Bipartisan, but mostly Democratic'], inplace=True)

dfgr
# Out:
#         Party      Amount
# 5  Republican  34246016.0
# 3    Democrat  10113639.0
# 0  Bipartisan   1474699.0

# %%
plt.bar(dfgr['Party'],dfgr['Amount'])
# Out:
# <BarContainer object of 3 artists>
